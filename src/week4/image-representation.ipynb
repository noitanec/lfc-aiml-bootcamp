# %%
from PIL import Image
import numpy as np

# %%
fpath = "/home/leapfrog/yak/lfc-aiml-bootcamp/src/data/images/messi.jpg"

image = Image.open(fpath)
image.show()

# %%
img = np.array(image)
img.shape
# Out:
# (2160, 1618, 3)

# %%
import cv2

img = cv2.imread(fpath)
# img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt

plt.imshow(img)
plt.axis("off")
plt.show()

# %%
print(img.shape)
# Out:
# (2160, 1618, 3)

# %%
img = cv2.imread(fpath, cv2.IMREAD_GRAYSCALE)

plt.imshow(img, cmap='gray')
plt.axis("off")
plt.show()

# %%
img.shape
# Out:
# (2160, 1618)

# %%
img[0]
# Out:
# array([41, 52, 60, ..., 71, 56, 44], shape=(1618,), dtype=uint8)
